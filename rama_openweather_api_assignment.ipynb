# %% [markdown]
# ## API-Based Weather Data Processing and Export to Excel
#
# #### This notebook uses an API to get weather forecast data for a city, processes it, and saves it into an Excel file
#
# #### Simple Explanation of the Code:
#
# | Step | Description |
# |------|-------------|
# | **1. Import Libraries** | - `requests`: Fetches weather data from the internet.<br> - `pandas`: Organizes and processes the data into tables.<br> - `json`: Formats and handles the data from the API. |
# | **2. Connect to the Weather API** | - Use an API key to access weather forecast data from OpenWeatherMap.<br> - Build the URL with the city ID and other parameters. |
# | **3. Fetch Weather Data** | - Send a request to the API to get the weather data.<br> - Convert the response (JSON format) into Python-friendly data (lists, dict). |
# | **4. Print the Data** | - Display the raw weather data in a neat and readable format using `json.dumps(data, indent=4)` for better readability. |
# | **5. Extract Specific Information** | - Gather useful data like temperature, humidity, weather description, wind speed, etc., for each time slot.<br> - Store this extracted data in a list. |
# | **6. Create a Table (DataFrame)** | - Use pandas to organize the extracted data into a structured table with rows and columns. |
# | **7. Filter by Time (12 PM)** | - Select rows where the weather data is recorded at 12:00 PM every day. |
# | **8. Separate Weather Types** | - Split the data into separate tables for:<br>   - Snowy conditions.<br>   - Rainy conditions.<br>   - Cloudy conditions. |
# | **9. Save to Excel** | - Save all the data into an Excel file with multiple sheets:<br>   - A sheet for the full weather data.<br>   - Separate sheets for Snow, Rain, and Clouds. |
# | **10. Final Output** | - Print a confirmation that the data has been saved into the Excel file. |

# %%
# Import necessary libraries
import requests  # To send HTTP requests
import pandas as pd  # To handle data and create DataFrames
import json  # To handle JSON data

# Install required libraries (in case you need them)
# !pip install pandas
# !pip install requests
# Out:
# Requirement already satisfied: pandas in c:\users\44773\myenv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\44773\myenv\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\44773\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\44773\myenv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\44773\myenv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\44773\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in c:\users\44773\myenv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\44773\myenv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\44773\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\44773\myenv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\44773\myenv\lib\site-packages (from requests) (2024.12.14)

# %%
# Define the API key to authenticate the request
API_key = 'd8bfc2a558b8aab911f2e4674842e261'

# Create the URL for making the request to the OpenWeather API
# The URL contains the API key, a city ID (524901 corresponds to Moscow), and the weather forecast endpoint
url = f'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={API_key}'

# Print the constructed URL to verify it
print(url)

# Send an HTTP GET request to the OpenWeather API using the constructed URL
response = requests.get(url)

# Print the response object to check the status and content of the response
print(response)
# Out:
# http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=d8bfc2a558b8aab911f2e4674842e261
# <Response [200]>

# %%
# Converts the JSON response into a Python dictionary
data = response.json()

# %%
# This will show the structure of the response and can be used to check the contents of the response.
#print(data)

# %%
print(type(data)) ## This helps to confirm that the response was parsed correctly and is now in dictionary format

# Use json.dumps() to pretty-print the JSON data with an indentation of 4 spaces.
# This will format the JSON data in a more human-readable way, which can be useful for viewing the entire structure.
print(json.dumps(data, indent=4))
# Out:
# <class 'dict'>
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1737039600,
#             "main": {
#                 "temp": 273.8,
#                 "feels_like": 268.55,
#                 "temp_min": 273.8,
#                 "temp_max": 273.97,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 994,
#                 "humidity": 80,
#                 "temp_kf": -0.17
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.94,
#                 "deg": 266,
#                 "gust": 13.77
#             },
#             "visibility": 10000,
#             "pop": 1,
#             "rain": {
#                 "3h": 0.54
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-16 15:00:00"
#         },
#         {
#             "dt": 1737050400,
#             "main": {
#                 "temp": 274.27,
#                 "feels_like": 269.1,
#                 "temp_min": 274.27,
#                 "temp_max": 274.54,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 993,
#                 "humidity": 87,
#                 "temp_kf": -0.27
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.05,
#                 "deg": 277,
#                 "gust": 15.17
#             },
#             "visibility": 10000,
#             "pop": 1,
#             "rain": {
#                 "3h": 0.26
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-16 18:00:00"
#         },
#         {
#             "dt": 1737061200,
#             "main": {
#                 "temp": 274.84,
#                 "feels_like": 270.15,
#                 "temp_min": 274.84,
#                 "temp_max": 274.84,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 993,
#                 "humidity": 97,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.38,
#                 "deg": 283,
#                 "gust": 13.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-16 21:00:00"
#         },
#         {
#             "dt": 1737072000,
#             "main": {
#                 "temp": 275.14,
#                 "feels_like": 270.1,
#                 "temp_min": 275.14,
#                 "temp_max": 275.14,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 992,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.27,
#                 "deg": 277,
#                 "gust": 14.58
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-17 00:00:00"
#         },
#         {
#             "dt": 1737082800,
#             "main": {
#                 "temp": 275.71,
#                 "feels_like": 270.76,
#                 "temp_min": 275.71,
#                 "temp_max": 275.71,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 992,
#                 "humidity": 94,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.44,
#                 "deg": 300,
#                 "gust": 15.13
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "rain": {
#                 "3h": 0.22
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-17 03:00:00"
#         },
#         {
#             "dt": 1737093600,
#             "main": {
#                 "temp": 275.54,
#                 "feels_like": 270.99,
#                 "temp_min": 275.54,
#                 "temp_max": 275.54,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 993,
#                 "humidity": 95,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.46,
#                 "deg": 303,
#                 "gust": 13.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-17 06:00:00"
#         },
#         {
#             "dt": 1737104400,
#             "main": {
#                 "temp": 275.88,
#                 "feels_like": 271.3,
#                 "temp_min": 275.88,
#                 "temp_max": 275.88,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 994,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.7,
#                 "deg": 310,
#                 "gust": 12.28
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-17 09:00:00"
#         },
#         {
#             "dt": 1737115200,
#             "main": {
#                 "temp": 275.47,
#                 "feels_like": 270.84,
#                 "temp_min": 275.47,
#                 "temp_max": 275.47,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 995,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.59,
#                 "deg": 314,
#                 "gust": 13
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "rain": {
#                 "3h": 0.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-17 12:00:00"
#         },
#         {
#             "dt": 1737126000,
#             "main": {
#                 "temp": 274.79,
#                 "feels_like": 270.2,
#                 "temp_min": 274.79,
#                 "temp_max": 274.79,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 997,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.15,
#                 "deg": 322,
#                 "gust": 11.41
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-17 15:00:00"
#         },
#         {
#             "dt": 1737136800,
#             "main": {
#                 "temp": 274.06,
#                 "feels_like": 269.76,
#                 "temp_min": 274.06,
#                 "temp_max": 274.06,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 998,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 98
#             },
#             "wind": {
#                 "speed": 4.34,
#                 "deg": 316,
#                 "gust": 10.36
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-17 18:00:00"
#         },
#         {
#             "dt": 1737147600,
#             "main": {
#                 "temp": 274.09,
#                 "feels_like": 270.32,
#                 "temp_min": 274.09,
#                 "temp_max": 274.09,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 998,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 94
#             },
#             "wind": {
#                 "speed": 3.58,
#                 "deg": 302,
#                 "gust": 8.77
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-17 21:00:00"
#         },
#         {
#             "dt": 1737158400,
#             "main": {
#                 "temp": 274.45,
#                 "feels_like": 270.7,
#                 "temp_min": 274.45,
#                 "temp_max": 274.45,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 998,
#                 "humidity": 84,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 97
#             },
#             "wind": {
#                 "speed": 3.66,
#                 "deg": 307,
#                 "gust": 7.97
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-18 00:00:00"
#         },
#         {
#             "dt": 1737169200,
#             "main": {
#                 "temp": 273.87,
#                 "feels_like": 270.13,
#                 "temp_min": 273.87,
#                 "temp_max": 273.87,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 997,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 3.48,
#                 "deg": 267,
#                 "gust": 8.33
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-18 03:00:00"
#         },
#         {
#             "dt": 1737180000,
#             "main": {
#                 "temp": 273.47,
#                 "feels_like": 269.36,
#                 "temp_min": 273.47,
#                 "temp_max": 273.47,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 995,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 3.86,
#                 "deg": 251,
#                 "gust": 9.28
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-18 06:00:00"
#         },
#         {
#             "dt": 1737190800,
#             "main": {
#                 "temp": 274.53,
#                 "feels_like": 269.92,
#                 "temp_min": 274.53,
#                 "temp_max": 274.53,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 992,
#                 "humidity": 94,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.08,
#                 "deg": 248,
#                 "gust": 12.81
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-18 09:00:00"
#         },
#         {
#             "dt": 1737201600,
#             "main": {
#                 "temp": 275.03,
#                 "feels_like": 269.49,
#                 "temp_min": 275.03,
#                 "temp_max": 275.03,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 989,
#                 "humidity": 85,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 7.42,
#                 "deg": 290,
#                 "gust": 13.64
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-18 12:00:00"
#         },
#         {
#             "dt": 1737212400,
#             "main": {
#                 "temp": 274.95,
#                 "feels_like": 269.66,
#                 "temp_min": 274.95,
#                 "temp_max": 274.95,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 989,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.73,
#                 "deg": 313,
#                 "gust": 13.02
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-18 15:00:00"
#         },
#         {
#             "dt": 1737223200,
#             "main": {
#                 "temp": 274.25,
#                 "feels_like": 268.87,
#                 "temp_min": 274.25,
#                 "temp_max": 274.25,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 989,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.5,
#                 "deg": 311,
#                 "gust": 13.17
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "snow": {
#                 "3h": 0.17
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-18 18:00:00"
#         },
#         {
#             "dt": 1737234000,
#             "main": {
#                 "temp": 272.93,
#                 "feels_like": 266.85,
#                 "temp_min": 272.93,
#                 "temp_max": 272.93,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 990,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 7.24,
#                 "deg": 316,
#                 "gust": 13.93
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-18 21:00:00"
#         },
#         {
#             "dt": 1737244800,
#             "main": {
#                 "temp": 272.8,
#                 "feels_like": 266.81,
#                 "temp_min": 272.8,
#                 "temp_max": 272.8,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 991,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 6.95,
#                 "deg": 322,
#                 "gust": 13.13
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-19 00:00:00"
#         },
#         {
#             "dt": 1737255600,
#             "main": {
#                 "temp": 272.55,
#                 "feels_like": 266.63,
#                 "temp_min": 272.55,
#                 "temp_max": 272.55,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 992,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.63,
#                 "deg": 321,
#                 "gust": 12.32
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-19 03:00:00"
#         },
#         {
#             "dt": 1737266400,
#             "main": {
#                 "temp": 272.07,
#                 "feels_like": 266.5,
#                 "temp_min": 272.07,
#                 "temp_max": 272.07,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 994,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 5.67,
#                 "deg": 328,
#                 "gust": 11.22
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-19 06:00:00"
#         },
#         {
#             "dt": 1737277200,
#             "main": {
#                 "temp": 272.58,
#                 "feels_like": 267.75,
#                 "temp_min": 272.58,
#                 "temp_max": 272.58,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 996,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 71
#             },
#             "wind": {
#                 "speed": 4.63,
#                 "deg": 323,
#                 "gust": 10.47
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-19 09:00:00"
#         },
#         {
#             "dt": 1737288000,
#             "main": {
#                 "temp": 272.98,
#                 "feels_like": 268.15,
#                 "temp_min": 272.98,
#                 "temp_max": 272.98,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 996,
#                 "humidity": 77,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 40
#             },
#             "wind": {
#                 "speed": 4.78,
#                 "deg": 315,
#                 "gust": 9.97
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-19 12:00:00"
#         },
#         {
#             "dt": 1737298800,
#             "main": {
#                 "temp": 272.36,
#                 "feels_like": 267.73,
#                 "temp_min": 272.36,
#                 "temp_max": 272.36,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 997,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 13
#             },
#             "wind": {
#                 "speed": 4.24,
#                 "deg": 317,
#                 "gust": 10.23
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-19 15:00:00"
#         },
#         {
#             "dt": 1737309600,
#             "main": {
#                 "temp": 272.22,
#                 "feels_like": 268.39,
#                 "temp_min": 272.22,
#                 "temp_max": 272.22,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 997,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 12
#             },
#             "wind": {
#                 "speed": 3.16,
#                 "deg": 298,
#                 "gust": 8.83
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-19 18:00:00"
#         },
#         {
#             "dt": 1737320400,
#             "main": {
#                 "temp": 273.2,
#                 "feels_like": 269.35,
#                 "temp_min": 273.2,
#                 "temp_max": 273.2,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 997,
#                 "humidity": 76,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 64
#             },
#             "wind": {
#                 "speed": 3.43,
#                 "deg": 271,
#                 "gust": 9.22
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-19 21:00:00"
#         },
#         {
#             "dt": 1737331200,
#             "main": {
#                 "temp": 273.7,
#                 "feels_like": 269.7,
#                 "temp_min": 273.7,
#                 "temp_max": 273.7,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 997,
#                 "humidity": 94,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 56
#             },
#             "wind": {
#                 "speed": 3.77,
#                 "deg": 270,
#                 "gust": 11.6
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-20 00:00:00"
#         },
#         {
#             "dt": 1737342000,
#             "main": {
#                 "temp": 274.03,
#                 "feels_like": 269.52,
#                 "temp_min": 274.03,
#                 "temp_max": 274.03,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 997,
#                 "humidity": 94,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 47
#             },
#             "wind": {
#                 "speed": 4.68,
#                 "deg": 305,
#                 "gust": 11.77
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-20 03:00:00"
#         },
#         {
#             "dt": 1737352800,
#             "main": {
#                 "temp": 274.27,
#                 "feels_like": 270.15,
#                 "temp_min": 274.27,
#                 "temp_max": 274.27,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 999,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 74
#             },
#             "wind": {
#                 "speed": 4.14,
#                 "deg": 312,
#                 "gust": 10.89
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-20 06:00:00"
#         },
#         {
#             "dt": 1737363600,
#             "main": {
#                 "temp": 274.17,
#                 "feels_like": 270.74,
#                 "temp_min": 274.17,
#                 "temp_max": 274.17,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "grnd_level": 1001,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 3.16,
#                 "deg": 320,
#                 "gust": 8.74
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-20 09:00:00"
#         },
#         {
#             "dt": 1737374400,
#             "main": {
#                 "temp": 274.21,
#                 "feels_like": 271.05,
#                 "temp_min": 274.21,
#                 "temp_max": 274.21,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 1003,
#                 "humidity": 85,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 61
#             },
#             "wind": {
#                 "speed": 2.85,
#                 "deg": 336,
#                 "gust": 6.37
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-20 12:00:00"
#         },
#         {
#             "dt": 1737385200,
#             "main": {
#                 "temp": 272.38,
#                 "feels_like": 270.11,
#                 "temp_min": 272.38,
#                 "temp_max": 272.38,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 1005,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 12
#             },
#             "wind": {
#                 "speed": 1.77,
#                 "deg": 340,
#                 "gust": 3.53
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-20 15:00:00"
#         },
#         {
#             "dt": 1737396000,
#             "main": {
#                 "temp": 271.65,
#                 "feels_like": 271.65,
#                 "temp_min": 271.65,
#                 "temp_max": 271.65,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 1006,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 17
#             },
#             "wind": {
#                 "speed": 1.06,
#                 "deg": 32,
#                 "gust": 1.48
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-20 18:00:00"
#         },
#         {
#             "dt": 1737406800,
#             "main": {
#                 "temp": 271.25,
#                 "feels_like": 271.25,
#                 "temp_min": 271.25,
#                 "temp_max": 271.25,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 1006,
#                 "humidity": 79,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 22
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 132,
#                 "gust": 1.08
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-20 21:00:00"
#         },
#         {
#             "dt": 1737417600,
#             "main": {
#                 "temp": 271.15,
#                 "feels_like": 268.57,
#                 "temp_min": 271.15,
#                 "temp_max": 271.15,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 1006,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 22
#             },
#             "wind": {
#                 "speed": 1.85,
#                 "deg": 172,
#                 "gust": 3.57
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-21 00:00:00"
#         },
#         {
#             "dt": 1737428400,
#             "main": {
#                 "temp": 271.91,
#                 "feels_like": 268.82,
#                 "temp_min": 271.91,
#                 "temp_max": 271.91,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 1004,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 66
#             },
#             "wind": {
#                 "speed": 2.35,
#                 "deg": 172,
#                 "gust": 5.94
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2025-01-21 03:00:00"
#         },
#         {
#             "dt": 1737439200,
#             "main": {
#                 "temp": 272.9,
#                 "feels_like": 268.99,
#                 "temp_min": 272.9,
#                 "temp_max": 272.9,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "grnd_level": 1002,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 3.43,
#                 "deg": 186,
#                 "gust": 9.98
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-21 06:00:00"
#         },
#         {
#             "dt": 1737450000,
#             "main": {
#                 "temp": 274.09,
#                 "feels_like": 269.55,
#                 "temp_min": 274.09,
#                 "temp_max": 274.09,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 999,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 4.75,
#                 "deg": 202,
#                 "gust": 11.83
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-21 09:00:00"
#         },
#         {
#             "dt": 1737460800,
#             "main": {
#                 "temp": 274.84,
#                 "feels_like": 270.28,
#                 "temp_min": 274.84,
#                 "temp_max": 274.84,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 995,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 5.13,
#                 "deg": 216,
#                 "gust": 13.62
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2025-01-21 12:00:00"
#         }
#     ],
#     "city": {
#         "id": 524901,
#         "name": "Moscow",
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "population": 0,
#         "timezone": 10800,
#         "sunrise": 1737006489,
#         "sunset": 1737034199
#     }
# }

# %%
# Create an empty list to store weather data
weather_data = []

# Loop through the data and extract useful weather information
for item in data['list']:
    weather_data.append({
        "datetime": item.get("dt_txt", ""),  # Date and time of the forecasted data
        "temp": item.get("main", {}).get("temp", 0),  # Temperature
        "feels_like": item.get("main", {}).get("feels_like", 0),  # Feels like temperature
        "temp_min": item.get("main", {}).get("temp_min", 0),  # Minimum temperature
        "temp_max": item.get("main", {}).get("temp_max", 0),  # Maximum temperature
        "pressure": item.get("main", {}).get("pressure", 0),  # Atmospheric pressure
        "humidity": item.get("main", {}).get("humidity", 0),  # Humidity percentage
        "weather_main": item.get("weather", [{}])[0].get("main", ""),  # Main weather condition (e.g., Rain, Snow)
        "weather_description": item.get("weather", [{}])[0].get("description", ""),  # Detailed weather description
        "clouds": item.get("clouds", {}).get("all", 0),  # Cloudiness percentage
        "wind_speed": item.get("wind", {}).get("speed", 0),  # Wind speed
        "wind_deg": item.get("wind", {}).get("deg", 0),  # Wind direction (degrees)
        "visibility": item.get("visibility", 0),  # Visibility in meters
        "pop": item.get("pop", 0),  # Probability of precipitation
        "snow_3h": item.get("snow", {}).get("3h", 0),  # Snowfall in the last 3 hours (if any)
    })

# %%
# Create a pandas DataFrame
df = pd.DataFrame(weather)

# Display the DataFrame
print(df.head())
# Out:
#               datetime    temp  feels_like  temp_min  temp_max  pressure  \
# 0  2025-01-16 12:00:00  273.42      268.19    273.41    273.42      1016
# 1  2025-01-16 15:00:00  273.60      268.30    273.60    273.97      1015
# 2  2025-01-16 18:00:00  274.17      268.97    274.17    274.54      1014
# 3  2025-01-16 21:00:00  274.84      270.15    274.84    274.84      1013
# 4  2025-01-17 00:00:00  275.14      270.10    275.14    275.14      1011
#
#    humidity weather_main weather_description  clouds  wind_speed  wind_deg  \
# 0        70         Snow          light snow     100        5.71       255
# 1        78         Rain          light rain     100        5.94       266
# 2        86         Rain          light rain     100        6.05       277
# 3        97       Clouds     overcast clouds     100        5.38       283
# 4        96       Clouds     overcast clouds     100        6.27       277
#
#    visibility  pop  snow_3h
# 0       10000  0.2     0.13
# 1       10000  1.0     0.00
# 2       10000  1.0     0.00
# 3       10000  0.0     0.00
# 4       10000  0.0     0.00

# %%
#dfilter the weather data at 12:00

# Ensure the 'datetime' column is in datetime format
df['datetime'] = pd.to_datetime(df['datetime'])

# Filter rows where the time is '12:00:00'
filtered_df = df[df['datetime'].dt.strftime('%H:%M:%S') == '12:00:00']

# Print the title and filtered data
print("Weather Data for 12:00:00 Time")
print(filtered_df)

# Write the filtered data to a CSV file
filtered_df.to_csv('filtered_weather_data_12_00.csv', index=False)

# Inform the user that the data has been saved
print("Filtered data has been written to 'filtered_weather_data_12_00.csv'!")
# Out:
# Weather Data for 12:00:00 Time
#                datetime    temp  feels_like  temp_min  temp_max  pressure  \
# 0   2025-01-16 12:00:00  273.42      268.19    273.41    273.42      1016
# 8   2025-01-17 12:00:00  275.47      270.84    275.47    275.47      1015
# 16  2025-01-18 12:00:00  275.03      269.49    275.03    275.03      1009
# 24  2025-01-19 12:00:00  272.98      268.15    272.98    272.98      1016
# 32  2025-01-20 12:00:00  274.21      271.05    274.21    274.21      1023
# 40  2025-01-16 12:00:00  273.42      268.19    273.41    273.42      1016
# 48  2025-01-17 12:00:00  275.47      270.84    275.47    275.47      1015
# 56  2025-01-18 12:00:00  275.03      269.49    275.03    275.03      1009
# 64  2025-01-19 12:00:00  272.98      268.15    272.98    272.98      1016
# 72  2025-01-20 12:00:00  274.21      271.05    274.21    274.21      1023
# 87  2025-01-17 12:00:00  275.47      270.84    275.47    275.47      1015
# 95  2025-01-18 12:00:00  275.03      269.49    275.03    275.03      1009
# 103 2025-01-19 12:00:00  272.98      268.15    272.98    272.98      1016
# 111 2025-01-20 12:00:00  274.21      271.05    274.21    274.21      1023
# 119 2025-01-21 12:00:00  274.84      270.28    274.84    274.84      1015
#
#      humidity weather_main weather_description  clouds  wind_speed  wind_deg  \
# 0          70         Snow          light snow     100        5.71       255
# 8          90         Rain          light rain     100        5.59       314
# 16         85       Clouds     overcast clouds     100        7.42       290
# 24         77       Clouds    scattered clouds      40        4.78       315
# 32         85       Clouds       broken clouds      61        2.85       336
# 40         70         Snow          light snow     100        5.71       255
# 48         90         Rain          light rain     100        5.59       314
# 56         85       Clouds     overcast clouds     100        7.42       290
# 64         77       Clouds    scattered clouds      40        4.78       315
# 72         85       Clouds       broken clouds      61        2.85       336
# 87         90         Rain          light rain     100        5.59       314
# 95         85       Clouds     overcast clouds     100        7.42       290
# 103        77       Clouds    scattered clouds      40        4.78       315
# 111        85       Clouds       broken clouds      61        2.85       336
# 119        80       Clouds     overcast clouds      99        5.13       216
#
#      visibility  pop  snow_3h
# 0         10000  0.2     0.13
# 8         10000  0.2     0.00
# 16        10000  0.0     0.00
# 24        10000  0.0     0.00
# 32        10000  0.0     0.00
# 40        10000  0.2     0.13
# 48        10000  0.2     0.00
# 56        10000  0.0     0.00
# 64        10000  0.0     0.00
# 72        10000  0.0     0.00
# 87        10000  0.2     0.00
# 95        10000  0.0     0.00
# 103       10000  0.0     0.00
# 111       10000  0.0     0.00
# 119       10000  0.0     0.00
# Filtered data has been written to 'filtered_weather_data_12_00.csv'!

# %%
# Filter the data based on the weather conditions
snow_df = df[df['weather_main'] == 'Snow']
rain_df = df[df['weather_main'] == 'Rain']
clouds_df = df[df['weather_main'] == 'Clouds']

# Specify the file path
file_path = 'weather_data.xlsx'

# Install xlsxwriter
# !pip install xlsxwriter

# Write the full weather data to the 'Full Data' sheet and filtered data to separate sheets
with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
    # Save the full weather data to the 'Full Data' sheet
    df.to_excel(writer, sheet_name='Full Data', index=False)

    # Save the filtered Snow data to the 'Snow' sheet
    snow_df.to_excel(writer, sheet_name='Snow', index=False, header=True)

    # Save the filtered Rain data to the 'Rain' sheet
    rain_df.to_excel(writer, sheet_name='Rain', index=False, header=True)

    # Save the filtered Clouds data to the 'Clouds' sheet
    clouds_df.to_excel(writer, sheet_name='Clouds', index=False, header=True)

print("Data has been written to the Excel file with multiple sheets!")
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\44773\myenv\lib\site-packages (3.2.0)
# Data has been written to the Excel file with multiple sheets!
